# %% [markdown]
# # TODOs

# %%
# hacer gráfica de overlapping para todas las distribuciones de propensity score

# %%
fig, ax = plt.subplots(figsize=(8, 1.3))


ax.set_yticks([0,1], ["Control", "Tratamiento"], color='gray')

ax.set_ylim(bottom=-0.5, top=1.5)
ax.spines.top.set_visible(False)
ax.spines.right.set_visible(False)
ax.spines.left.set_visible(False)
ax.spines.bottom.set_color("gray")
ax.tick_params(axis='y', size=0) 

color={
    0:"#3d5a80",
    1:"#6a994e"
}

ax.scatter(
    ps_matcher.propensity_score.propensity_score,
    ps_matcher.propensity_score.has_camera,
    marker='|',
    s=100,
    alpha=.2,
    color=ps_matcher.propensity_score.has_camera.map(color)
)

ax.set_xlabel("Propensity score")
fig.tight_layout()

plt.show()
